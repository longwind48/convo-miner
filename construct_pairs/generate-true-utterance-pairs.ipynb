# %% [markdown]
# The notebook generates utterance pairs from tagged utterances, where tags are {B-START, I-START, B-OTHER, I-OTHER, O}.
#
# From the start of every conversation, i.e. utterances with B-START tag, an utterance-reponse pair is construct by assuming the next utterance in the conversation is a reponse. We stop the pairing if we reach the end of the conversation.
#
# e.g.

# %% [markdown]
# # Import Libraries and Data

# %%
import pandas as pd
import os
import datetime
pd.set_option('display.max_colwidth', -1)
pd.set_option("display.max_rows", 1000)

# %%
df_to_generate = pd.read_csv('../data/labeled/iob-labeled-sent-final-060519-v2.csv', index_col=[0])

# %%
df_to_generate.head()
# Out:
#    old_para_index  para_index  \
# 0  0               0
# 1  63              1
# 2  64              2
# 3  65              3
# 4  66              4
#
#                                                                                                                                                                                                                                                                                   sent  \
# 0  By Jane Austen
# 1  Chapter 1
# 2  It is a truth universally acknowledged, that a single man in possession of       a good fortune, must be in want of a wife.
# 3  However little known the feelings or views of such a man may be on his       first entering a neighbourhood, this truth is so well fixed in the minds       of the surrounding families, that he is considered the rightful property       of some one or other of their daughters.
# 4  "My dear Mr Bennet,"
#
#      label split_tag
# 0  O        train
# 1  O        train
# 2  O        train
# 3  O        train
# 4  B-START  train

# %%
df_to_generate.loc[91:95]
# Out:
#     old_para_index  para_index  \
# 91  134             72
# 92  134             72
# 93  135             73
# 94  136             74
# 95  136             74
#
#                                                                                                                                                                                                                                                                                                                sent  \
# 91  "Come, Darcy,"
# 92  "I must have you dance. I hate to see you standing       about by yourself in this stupid manner. You had much better dance."
# 93  "I certainly shall not. You know how I detest it, unless I am particularly       acquainted with my partner. At such an assembly as this it would be       insupportable. Your sisters are engaged, and there is not another woman in       the room whom it would not be a punishment to me to stand up with."
# 94  "I would not be so fastidious as you are,"
# 95  "for a       kingdom! Upon my honour, I never met with so many pleasant girls in my       life as I have this evening; and there are several of them you see       uncommonly pretty."
#
#       label split_tag
# 91  B-START  train
# 92  I-START  train
# 93  B-OTHER  train
# 94  B-OTHER  train
# 95  I-OTHER  train

# %%
def add_chapters(df):
    chapter_dict = dict()
    chapter_tag = ''
    for i in df.index:
        curr_chapter_tag = df.loc[i]['chapter_tag']
        if curr_chapter_tag == '':
            if chapter_tag != '':
                chapter_dict[i] = chapter_tag
            else:
                chapter_tag = curr_chapter_tag
                chapter_dict[i] = chapter_tag
        else:
            if chapter_tag == curr_chapter_tag:
                chapter_dict[i] = chapter_tag
            else:
                chapter_tag = curr_chapter_tag
                chapter_dict[i] = chapter_tag
    return chapter_dict

# %%
df_to_generate['chapter_tag'] = df_to_generate['sent'].apply(lambda x: x if 'chapter ' in x.lower() else '')
df_to_generate['chapter_tag'] = list(x[1] for x in add_chapters(df_to_generate).items())

# %% [markdown]
# # Generate Utterance Pairs

# %%
df_utter = df_to_generate[df_to_generate['label']!='O']
utter_list = list(df_utter.apply(lambda row: row['sent'], axis=1).values)

print('Number of utterances: {}'.format(len(utter_list)))

utter_pair_list = []
for idx, i in enumerate(utter_list):
    if idx < (len(utter_list)-1):
        utter_pair_list.append((i,)+(utter_list[idx+1],))
utter_pair_list.append(('',)+('',))

df_pairs = pd.DataFrame()
df_pairs['utter_1'] = [x[0] for x in utter_pair_list]
df_pairs['utter_2'] = [x[1] for x in utter_pair_list]
df_pairs['label'] = df_utter['label'].values
df_pairs['chapter_tag'] = df_utter['chapter_tag'].values

indices_to_rm = []
for i in df_pairs.index:
    if (df_pairs.loc[i]['label'] == 'B-START') & (i!=0):
        indices_to_rm.append(i-1)

df_pairs = df_pairs.drop(indices_to_rm, axis=0)
df_pairs = df_pairs.reset_index()
del df_pairs['index']

test_set_chapters = ['Chapter {}'.format(x) for x in range(19,27)]
validation_set_chapters = ['Chapter {}'.format(x) for x in range(27,34)]
def custom_train_test_split(field):
    if field in test_set_chapters:
        return 'test'
    elif field in validation_set_chapters:
        return 'validation'
    else:
        return 'train'
df_pairs['split_tag'] = df_pairs['chapter_tag'].apply(lambda x: custom_train_test_split(x))

print('Generated {} utterance pairs'.format(df_pairs.shape[0]))

print('Saving to csv..')

# Save as csv
NAME = 'true'
dirname = os.path.dirname('__file__')
output_path = os.path.join(dirname, '../data/utterance_pairs/')
current_year = str(datetime.datetime.now())[0:10]
csv_name = '{}-utter-pairs-{}.csv'.format(NAME, current_year)
df_pairs.to_csv(output_path + csv_name)

print('Done')
# Out:
# Number of utterances: 1740
# Generated 1512 utterance pairs
# Saving to csv..
# Done

# %% [markdown]
# # Preview

# %%
# preview
df_pairs_true = pd.read_csv('../data/utterance_pairs/true-utter-pairs-2019-05-06.csv', index_col=[0])

# %%
df_pairs_true.head(50)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                        utter_1  \
# 0   "My dear Mr Bennet,"
# 1   "have you heard that       Netherfield Park is let at last?"
# 2   "But it is,"
# 3   "for Mrs Long has just been here, and she told       me all about it."
# 4   "Do you not want to know who has taken it?"
# 5   "You want to tell me, and I have no objection to hearing it."
# 6   "Why, my dear, you must know, Mrs Long says that Netherfield is taken by       a young man of large fortune from the north of England; that he came down       on Monday in a chaise and four to see the place, and was so much delighted       with it, that he agreed with Mr Morris immediately; that he is to take       possession before Michaelmas, and some of his servants are to be in the       house by the end of next week."
# 7   "What is his name?"
# 8   "Bingley."
# 9   "Is he married or single?"
# 10  "Oh! Single, my dear, to be sure! A single man of large fortune; four or       five thousand a year. What a fine thing for our girls!"
# 11  "How so? How can it affect them?"
# 12  "My dear Mr Bennet,"
# 13  "how can you be so tiresome! You       must know that I am thinking of his marrying one of them."
# 14  "Is that his design in settling here?"
# 15  "Design! Nonsense, how can you talk so! But it is very likely that he may       fall in love with one of them, and therefore you must visit him as soon as       he comes."
# 16  "I see no occasion for that. You and the girls may go, or you may send       them by themslves, which perhaps will be still better, for as you are as       handsome as any of them, Mr Bingley may like you the best of the party."
# 17  "My dear, you flatter me. I certainly have had my share of beauty,       but I do not pretend to be anything extraordinary now. When a woman has       five grown-up daughters, she ought to give over thinking of her own       beauty."
# 18  "In such cases, a woman has not often much beauty to think of."
# 19  "But, my dear, you must indeed go and see Mr Bingley when he comes into       the neighbourhood."
# 20  "It is more than I engage for, I assure you."
# 21  "But consider your daughters. Only think what an establishment it would be       for one of them. Sir William and Lady Lucas are determined to go, merely       on that account, for in general, you know, they visit no newcomers. Indeed       you must go, for it will be impossible for us to visit him if you       do not."
# 22  "You are over-scrupulous, surely. I dare say Mr Bingley will be very glad       to see you; and I will send a few lines by you to assure him of my hearty       consent to his marrying whichever he chooses of the girls; though I must       throw in a good word for my little Lizzy."
# 23  "I desire you will do no such thing. Lizzy is not a bit better than the       others; and I am sure she is not half so handsome as Jane, nor half so       good-humoured as Lydia. But you are always giving her the       preference."
# 24  "They have none of them much to recommend them,"
# 25  "they are all       silly and ignorant like other girls; but Lizzy has something more of       quickness than her sisters."
# 26  "Mr Bennet, how can you abuse your own children in such a way? You       take delight in vexing me. You have no compassion for my poor nerves."
# 27  "You mistake me, my dear. I have a high respect for your nerves. They are       my old friends. I have heard you mention them with consideration these       last twenty years at least."
# 28  "Ah, you do not know what I suffer."
# 29  "But I hope you will get over it, and live to see many young men of four       thousand a year come into the neighbourhood."
# 30  "It will be no use to us, if twenty such should come, since you will not       visit them."
# 31  "I hope Mr Bingley will like it, Lizzy."
# 32  "We are not in a way to know what Mr Bingley likes,"
# 33  "since we are not to visit."
# 34  "But you forget, mamma,"
# 35  "that we shall meet him at the       assemblies, and that Mrs Long promised to introduce him."
# 36  "I do not believe Mrs Long will do any such thing. She has two nieces of       her own. She is a selfish, hypocritical woman, and I have no opinion of       her."
# 37  "No more have I,"
# 38  "Don't keep coughing so, Kitty, for Heaven's sake! Have a little       compassion on my nerves. You tear them to pieces."
# 39  "Kitty has no discretion in her coughs,"
# 40  "she times them       ill."
# 41  "I do not cough for my own amusement,"
# 42  "When is       your next ball to be, Lizzy?"
# 43  "To-morrow fortnight."
# 44  "Aye, so it is,"
# 45  "and Mrs Long does not come back till       the day before; so it will be impossible for her to introduce him, for she       will not know him herself."
# 46  "Then, my dear, you may have the advantage of your friend, and introduce       Mr Bingley to her."
# 47  "Impossible, Mr Bennet, impossible, when I am not acquainted with him       myself; how can you be so teasing?"
# 48  "I honour your circumsection. A fortnight's acquaintance is certainly       very little. One cannot know what a man really is by the end of a       fortnight. But if we do not venture somebody else will; and after       all, Mrs Long and her nieces must stand their chance; and, therefore,       as she will think it an act of kindness, if you decline the office, I will       take it on myself."
# 49  "Nonsense,       nonsense!"
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                        utter_2  \
# 0   "have you heard that       Netherfield Park is let at last?"
# 1   "But it is,"
# 2   "for Mrs Long has just been here, and she told       me all about it."
# 3   "Do you not want to know who has taken it?"
# 4   "You want to tell me, and I have no objection to hearing it."
# 5   "Why, my dear, you must know, Mrs Long says that Netherfield is taken by       a young man of large fortune from the north of England; that he came down       on Monday in a chaise and four to see the place, and was so much delighted       with it, that he agreed with Mr Morris immediately; that he is to take       possession before Michaelmas, and some of his servants are to be in the       house by the end of next week."
# 6   "What is his name?"
# 7   "Bingley."
# 8   "Is he married or single?"
# 9   "Oh! Single, my dear, to be sure! A single man of large fortune; four or       five thousand a year. What a fine thing for our girls!"
# 10  "How so? How can it affect them?"
# 11  "My dear Mr Bennet,"
# 12  "how can you be so tiresome! You       must know that I am thinking of his marrying one of them."
# 13  "Is that his design in settling here?"
# 14  "Design! Nonsense, how can you talk so! But it is very likely that he may       fall in love with one of them, and therefore you must visit him as soon as       he comes."
# 15  "I see no occasion for that. You and the girls may go, or you may send       them by themslves, which perhaps will be still better, for as you are as       handsome as any of them, Mr Bingley may like you the best of the party."
# 16  "My dear, you flatter me. I certainly have had my share of beauty,       but I do not pretend to be anything extraordinary now. When a woman has       five grown-up daughters, she ought to give over thinking of her own       beauty."
# 17  "In such cases, a woman has not often much beauty to think of."
# 18  "But, my dear, you must indeed go and see Mr Bingley when he comes into       the neighbourhood."
# 19  "It is more than I engage for, I assure you."
# 20  "But consider your daughters. Only think what an establishment it would be       for one of them. Sir William and Lady Lucas are determined to go, merely       on that account, for in general, you know, they visit no newcomers. Indeed       you must go, for it will be impossible for us to visit him if you       do not."
# 21  "You are over-scrupulous, surely. I dare say Mr Bingley will be very glad       to see you; and I will send a few lines by you to assure him of my hearty       consent to his marrying whichever he chooses of the girls; though I must       throw in a good word for my little Lizzy."
# 22  "I desire you will do no such thing. Lizzy is not a bit better than the       others; and I am sure she is not half so handsome as Jane, nor half so       good-humoured as Lydia. But you are always giving her the       preference."
# 23  "They have none of them much to recommend them,"
# 24  "they are all       silly and ignorant like other girls; but Lizzy has something more of       quickness than her sisters."
# 25  "Mr Bennet, how can you abuse your own children in such a way? You       take delight in vexing me. You have no compassion for my poor nerves."
# 26  "You mistake me, my dear. I have a high respect for your nerves. They are       my old friends. I have heard you mention them with consideration these       last twenty years at least."
# 27  "Ah, you do not know what I suffer."
# 28  "But I hope you will get over it, and live to see many young men of four       thousand a year come into the neighbourhood."
# 29  "It will be no use to us, if twenty such should come, since you will not       visit them."
# 30  "Depend upon it, my dear, that when there are twenty, I will visit them       all."
# 31  "We are not in a way to know what Mr Bingley likes,"
# 32  "since we are not to visit."
# 33  "But you forget, mamma,"
# 34  "that we shall meet him at the       assemblies, and that Mrs Long promised to introduce him."
# 35  "I do not believe Mrs Long will do any such thing. She has two nieces of       her own. She is a selfish, hypocritical woman, and I have no opinion of       her."
# 36  "No more have I,"
# 37  "and I am glad to find that you do not       depend on her serving you."
# 38  "Kitty has no discretion in her coughs,"
# 39  "she times them       ill."
# 40  "I do not cough for my own amusement,"
# 41  "When is       your next ball to be, Lizzy?"
# 42  "To-morrow fortnight."
# 43  "Aye, so it is,"
# 44  "and Mrs Long does not come back till       the day before; so it will be impossible for her to introduce him, for she       will not know him herself."
# 45  "Then, my dear, you may have the advantage of your friend, and introduce       Mr Bingley to her."
# 46  "Impossible, Mr Bennet, impossible, when I am not acquainted with him       myself; how can you be so teasing?"
# 47  "I honour your circumsection. A fortnight's acquaintance is certainly       very little. One cannot know what a man really is by the end of a       fortnight. But if we do not venture somebody else will; and after       all, Mrs Long and her nieces must stand their chance; and, therefore,       as she will think it an act of kindness, if you decline the office, I will       take it on myself."
# 48  "Nonsense,       nonsense!"
# 49  "What can be the meaning of that emphatic exclamation?"
#
#       label chapter_tag split_tag
# 0   B-START  Chapter 1   train
# 1   I-START  Chapter 1   train
# 2   B-OTHER  Chapter 1   train
# 3   I-OTHER  Chapter 1   train
# 4   B-OTHER  Chapter 1   train
# 5   B-OTHER  Chapter 1   train
# 6   B-OTHER  Chapter 1   train
# 7   B-OTHER  Chapter 1   train
# 8   B-OTHER  Chapter 1   train
# 9   B-OTHER  Chapter 1   train
# 10  B-OTHER  Chapter 1   train
# 11  B-OTHER  Chapter 1   train
# 12  B-OTHER  Chapter 1   train
# 13  I-OTHER  Chapter 1   train
# 14  B-OTHER  Chapter 1   train
# 15  B-OTHER  Chapter 1   train
# 16  B-OTHER  Chapter 1   train
# 17  B-OTHER  Chapter 1   train
# 18  B-OTHER  Chapter 1   train
# 19  B-OTHER  Chapter 1   train
# 20  B-OTHER  Chapter 1   train
# 21  B-OTHER  Chapter 1   train
# 22  B-OTHER  Chapter 1   train
# 23  B-OTHER  Chapter 1   train
# 24  B-OTHER  Chapter 1   train
# 25  I-OTHER  Chapter 1   train
# 26  B-OTHER  Chapter 1   train
# 27  B-OTHER  Chapter 1   train
# 28  B-OTHER  Chapter 1   train
# 29  B-OTHER  Chapter 1   train
# 30  B-OTHER  Chapter 1   train
# 31  B-START  Chapter 2   train
# 32  B-OTHER  Chapter 2   train
# 33  I-OTHER  Chapter 2   train
# 34  B-OTHER  Chapter 2   train
# 35  I-OTHER  Chapter 2   train
# 36  B-OTHER  Chapter 2   train
# 37  B-OTHER  Chapter 2   train
# 38  B-START  Chapter 2   train
# 39  B-OTHER  Chapter 2   train
# 40  I-OTHER  Chapter 2   train
# 41  B-OTHER  Chapter 2   train
# 42  I-OTHER  Chapter 2   train
# 43  B-OTHER  Chapter 2   train
# 44  B-OTHER  Chapter 2   train
# 45  I-OTHER  Chapter 2   train
# 46  B-OTHER  Chapter 2   train
# 47  B-OTHER  Chapter 2   train
# 48  B-OTHER  Chapter 2   train
# 49  B-OTHER  Chapter 2   train

# %%
df_pairs_true_test =  df_pairs_true[df_pairs_true['split_tag']=='test']

# %%
df_pairs_true_test.shape
# Out:
# (148, 5)
